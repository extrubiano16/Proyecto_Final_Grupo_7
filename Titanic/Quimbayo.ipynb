# %%
import pandas as pd

df = pd.read_csv("test.csv")

print(df['Pclass'].value_counts().to_string())
# Out:
# Pclass
# 3    218
# 1    107
# 2     93

# %%
import pandas as pd

df = pd.read_csv("test.csv")

print(df.groupby('Sex')['Age'].mean().to_string())
# Out:
# Sex
# female    30.272362
# male      30.272732
