# %%
import pandas as pd

df = pd.read_csv("test.csv")

conteo_pclass = df.groupby('Pclass').size()
print(conteo_pclass.to_string())
# Out:
# Pclass
# 1    107
# 2     93
# 3    218

# %%
edad_promedio_sexo = df.groupby('Sex')['Age'].mean()
print(edad_promedio_sexo.to_string())
# Out:
# Sex
# female    30.272362
# male      30.272732
