# %%
import pandas as pd

# %%
df = pd.read_csv("/workspaces/Proyecto_Final_Grupo_7/Titanic/test.csv")

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
print(df.columns.tolist())
# Out:
# ['passengerid', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked']

# %%
df.groupby('pclass')['fare'].sum()
df.groupby(['embarked', 'sex'])['fare'].mean()
# Out:
# embarked  sex
# C         female    92.003230
#           male      49.651077
# Q         female    12.424654
#           male       9.357386
# S         female    40.719651
#           male      22.158332
# Name: fare, dtype: float64

# %%
df.groupby('pclass')['fare'].sum()
# Out:
# pclass
# 1    10087.9918
# 2     2064.7957
# 3     2703.7501
# Name: fare, dtype: float64

# %%
df.groupby(['embarked', 'sex'])['fare'].mean()
# Out:
# embarked  sex
# C         female    92.003230
#           male      49.651077
# Q         female    12.424654
#           male       9.357386
# S         female    40.719651
#           male      22.158332
# Name: fare, dtype: float64
