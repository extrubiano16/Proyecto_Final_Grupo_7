# %%
import pandas as pd

# %%
df = pd.read_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv")

# %%
def suma_digitos(valor):
    return sum(int(digito) for digito in str(valor) if digito.isdigit())

# %%
df['n'] = df['Número de documento'].apply(suma_digitos)

# %%
def totall(n):
    x = 105
    tot = n * x**2 + 2 * x + 23
    
    x = 100
    tota = n * x**2 + 2 * x + 23
    
    total = (tot - tota) / 5
    
    return round(total, 2)

# %%
df["P1"] = df["n"].apply(totall)

# %%
df["Resultado-1"] = (df[df.columns[1]] == df["P1"]) * 5

# %%
def C(x, n):
    return n * x**2 + 2*x + 23

def cp2(n):
    return round(C(101, n) - C(100, n), 2)

def cp3(n):   
    return round(200*n + 2, 2)

# %%
df["P2"] = df["n"].apply(cp2)

# %%
df = df.drop(columns=["CP2", "Calificacion2"], errors="ignore")

# %%
df["Resultado-2"] = (df[df.columns[2]] == df["P2"]) * 5

# %%
df["P3"] = df["n"].apply(cp3)

# %%
df["Resultado-3"] = (df[df.columns[3]] == df["P3"]) * 5

# %%
Samuel=df

# %%
Samuel
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# 6                                            7382.000
# 7                                          389866.330
# 8                                            6356.600
# 9                                            8407.000
# 10                                              6.357
# 11                                          10047.000
# 12                                           7177.000
# 13                                           6357.000
# 14                                           7587.000
# 15                                           5740.000
# 16                                            175.000
# 17                                           7382.000
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                            7238.000
# 1                                            8645.000
# 2                                            8444.000
# 3                                            4826.000
# 4                                            5429.000
# 5                                            6233.000
# 6                                            7238.000
# 7                                            3739.230
# 8                                            6233.000
# 9                                            8243.000
# 10                                              6.233
# 11                                           9851.000
# 12                                           7037.000
# 13                                           6233.000
# 14                                           7439.000
# 15                                           5620.000
# 16                                            152.000
# 17                                           7238.000
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \n<<<<<<< HEAD\nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                            7202.000
# 1                                            8602.000
# 2                                            8402.000
# 3                                            4802.000
# 4                                            5402.000
# 5                                            6202.000
# 6                                               2.000
# 7                                            7402.000
# 8                                              62.000
# 9                                            8202.000
# 10                                              6.202
# 11                                              2.000
# 12                                           7002.000
# 13                                           6202.000
# 14                                             76.000
# 15                                           5600.000
# 16                                              1.000
# 17                                            366.820
#
#      n       P1  Resultado-1    P2  Resultado-2    P3  Resultado-3  Nota_Final
# 0   36   7382.0            5  7238            5  7202            5    5.000000
# 1   43   8817.0            5  8645            5  8602            5    5.000000
# 2   42   8612.0            5  8444            5  8402            5    5.000000
# 3   24   4922.0            5  4826            5  4802            5    5.000000
# 4   27   5537.0            5  5429            5  5402            5    5.000000
# 5   31   6357.0            5  6233            5  6202            5    5.000000
# 6   36   7382.0            5  7238            5  7202            0    3.333333
# 7   37   7587.0            0  7439            0  7402            5    1.666667
# 8   31   6357.0            0  6233            5  6202            0    1.666667
# 9   41   8407.0            5  8243            5  8202            5    5.000000
# 10  31   6357.0            0  6233            0  6202            0    0.000000
# 11  49  10047.0            5  9851            5  9802            0    3.333333
# 12  35   7177.0            5  7037            5  7002            5    5.000000
# 13  31   6357.0            5  6233            5  6202            5    5.000000
# 14  37   7587.0            5  7439            5  7402            0    3.333333
# 15  28   5742.0            0  5630            0  5602            0    0.000000
# 16  38   7792.0            0  7640            0  7602            0    0.000000
# 17  36   7382.0            5  7238            5  7202            0    3.333333

# %%
Samuel.to_csv("quiz_limpio.csv", index=False)

# %%
df= df.rename(columns={'Resultado-2': 'CP2', 'Resultado-3': 'CP3'})

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# 6                                            7382.000
# 7                                          389866.330
# 8                                            6356.600
# 9                                            8407.000
# 10                                              6.357
# 11                                          10047.000
# 12                                           7177.000
# 13                                           6357.000
# 14                                           7587.000
# 15                                           5740.000
# 16                                            175.000
# 17                                           7382.000
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                            7238.000
# 1                                            8645.000
# 2                                            8444.000
# 3                                            4826.000
# 4                                            5429.000
# 5                                            6233.000
# 6                                            7238.000
# 7                                            3739.230
# 8                                            6233.000
# 9                                            8243.000
# 10                                              6.233
# 11                                           9851.000
# 12                                           7037.000
# 13                                           6233.000
# 14                                           7439.000
# 15                                           5620.000
# 16                                            152.000
# 17                                           7238.000
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \n<<<<<<< HEAD\nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                            7202.000
# 1                                            8602.000
# 2                                            8402.000
# 3                                            4802.000
# 4                                            5402.000
# 5                                            6202.000
# 6                                               2.000
# 7                                            7402.000
# 8                                              62.000
# 9                                            8202.000
# 10                                              6.202
# 11                                              2.000
# 12                                           7002.000
# 13                                           6202.000
# 14                                             76.000
# 15                                           5600.000
# 16                                              1.000
# 17                                            366.820
#
#      n       P1  Resultado-1    P2  CP2    P3  CP3  Nota_Final
# 0   36   7382.0            5  7238    5  7202    5    5.000000
# 1   43   8817.0            5  8645    5  8602    5    5.000000
# 2   42   8612.0            5  8444    5  8402    5    5.000000
# 3   24   4922.0            5  4826    5  4802    5    5.000000
# 4   27   5537.0            5  5429    5  5402    5    5.000000
# 5   31   6357.0            5  6233    5  6202    5    5.000000
# 6   36   7382.0            5  7238    5  7202    0    3.333333
# 7   37   7587.0            0  7439    0  7402    5    1.666667
# 8   31   6357.0            0  6233    5  6202    0    1.666667
# 9   41   8407.0            5  8243    5  8202    5    5.000000
# 10  31   6357.0            0  6233    0  6202    0    0.000000
# 11  49  10047.0            5  9851    5  9802    0    3.333333
# 12  35   7177.0            5  7037    5  7002    5    5.000000
# 13  31   6357.0            5  6233    5  6202    5    5.000000
# 14  37   7587.0            5  7439    5  7402    0    3.333333
# 15  28   5742.0            0  5630    0  5602    0    0.000000
# 16  38   7792.0            0  7640    0  7602    0    0.000000
# 17  36   7382.0            5  7238    5  7202    0    3.333333

# %%
df.to_csv("quiz_limpio.csv", index=False)

# %%
import matplotlib.pyplot as plt
from funciones import desviacion

# %%
columnas = ["CP1", "CP2", "CP3", "NF"]
desviaciones = [desviacion("quiz_limpio.csv", col) for col in columnas]
desviaciones = []
for col in columnas:
    valor = desviacion("quiz_limpio.csv", col)
    if isinstance(valor, (int, float)):
        desviaciones.append(valor)
    else:
        desviaciones.append(0)
plt.figure(figsize=(8,5))
plt.bar(columnas, desviaciones, color="blue")
plt.title("Desviaciones estándar de calificaciones (usando función)")
plt.ylabel("Desviación")
plt.xlabel("Puntos")
plt.savefig("Figuras/Desviaciones.png")
plt.show()
